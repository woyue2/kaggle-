# %% [markdown]
# 数学思想

# %%
## 数学思想 Sta

# %% [raw]
# 薄 厚 薄
# 式 图 式
# 中医 图来看

# %% [raw]
# 后续继续验证
# 学一遍
# 微积分   -- 函数图
# 线性袋鼠 -- 二维深浅布

# %%
## 数学思想 End

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
w -- weighted term
b -- bias term

# %% [markdown]
# plt超简单入门

# %%
# 
x = [1., 2., 3.]
y = [2., 5,  6]
plt.subplot(1,2,1)
plt.plot(x, y)
plt.subplot(1,2,2)
plt.plot(y, x)
plt.plot(x, y)

# %% [markdown]
# ```
# cost 损失函数
# ```

# %%
# 值遇 会在 0,1之间 越0越棒！

# %%
## 数学直觉 Sta

# %%
from helper.hanshu import 导, 画

# %%
x = sp.Symbol('x')
画(1-x)
画(x)
画(sp.log(x))
画(sp.log(1-x))
# Out:
# <lambdifygenerated-80>:2: RuntimeWarning: invalid value encountered in log
#   return log(x)
# <lambdifygenerated-81>:2: RuntimeWarning: invalid value encountered in log
#   return log(1 - x)
# 'Draw log(1 - x) !'

# %%
画(x*sp.log(x) + (1-x)*sp.log(1-x))
# Out:
# <lambdifygenerated-82>:2: RuntimeWarning: invalid value encountered in log
#   return x*log(x) + (1 - x)*log(1 - x)
# 'Draw x*log(x) + (1 - x)*log(1 - x) !'

# %%
画(-1*(x*sp.log(x) + (1-x)*sp.log(1-x))) 
# 本质 ： 权重 x  1-x
#        log 对数机率
# Out:
# <lambdifygenerated-83>:2: RuntimeWarning: invalid value encountered in log
#   return -x*log(x) - (1 - x)*log(1 - x)
# 'Draw -x*log(x) - (1 - x)*log(1 - x) !'

# %%
## 数学直觉 End

# %% [markdown]
# ```
# sigmoid 函数
# ```

# %%
## 数学直觉 Sta

# %%
import math
画(1 / math.e**(-x))
画(math.e**(-x))
# Out:
# 'Draw 2.71828182845905**(-x) !'

# %%
画((1 + math.e**(-x)))
画(1 /(1 + math.e**(-x)))
# 画(1 / math.e**(-x))
# Out:
# 'Draw 1/(1 + 2.71828182845905**(-x)) !'

# %%
画(1 /(1 + math.e**(-x)))
# Out:
# 'Draw 1/(1 + 2.71828182845905**(-x)) !'

# %%
f = 1 /(1 + math.e**(-x))
画(f)
f1 = 导(f)
画(f1)
f2 = 导(f1)
画(f2)
f3 = 导(f2)
画(f3)
f4 = 导(f3)
画(f4)
# Out:
# 'Draw -1.0/(2.71828182845905**x*(1 + 2.71828182845905**(-x))**2) + 14.0/(2.71828182845905**(2*x)*(1 + 2.71828182845905**(-x))**3) - 36.0/(2.71828182845905**(3*x)*(1 + 2.71828182845905**(-x))**4) + 24.0/(2.71828182845905**(4*x)*(1 + 2.71828182845905**(-x))**5) !'

# %% [raw]
# 1
# 对称 --> 奇函数 关于（0，1）的几函数
# 参考cosx 。。。。它会周而复始 就是接第二点的不断导的话
#
# 2
# f1跟f3的峰值位置对称, f2根f4也是
# 如果持续下去， 零点位置会不断增加！然后也是接近有对称的规律
#
# 3会发现 导数以后，数值会不断减少
#
# e是自然函数 所以它的衍生品也是有奇奇怪怪的自然现象 ，也是很像海潮是不是

# %%
## 数学直觉 End

# %% [raw]
# 梯度下降

# %%
身高跟岁数的关系
180 18岁
170 17岁
拟合
